# %%
1 + 1
# Out:
# 2

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# # This is the beginning of the end

# %%
##This is the beginning of the end

# %%
*This is the first bullet
*This is the second bullet
# Out:
#   File "<ipython-input-5-ff4db2df31b6>", line 1
#     *This is the first bullet
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# *This is the first bullet

# %% [markdown]
# *This is the second bullet
# *This is the third bullet
